# %% [markdown]
# <a href="https://colab.research.google.com/github/Marko2707/AutomatedChessDetection/blob/colabCV/ChessDetect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Get all necessary dependencies for the project to work

# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.2/910.2 kB 23.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %% [markdown]
# Running the yolov11 nano model on the dataset and testing it
#
# > Blockzitat einfügen

# %%
from ultralytics import YOLO
import torch

# Load the model
model = YOLO('yolo11n.pt')  # Load a pretrained yolo v11 nano model

# Train the model using the dataset URL (as of now not using our own database)
results = model.train(data='https://public.roboflow.com/ds/u5mL49RR1Y?key=PY0lMfxgre', epochs=5, device= torch.device('cuda'))

# Evaluate the model on the validation set
results = model.val()

# Print the results
print(results)
# Out:
# engine/trainer: task=detect, mode=train, model=yolo11n.pt, data=https://public.roboflow.com/ds/u5mL49RR1Y?key=PY0lMfxgre, epochs=5, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cuda, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=
# ...

# %% [markdown]
# Load Test Image

# %%
from google.colab import files

uploaded = files.upload()  #Select the image
# Out:
#      <input type="file" id="files-311296a1-a2d9-4069-86de-2918aa6e10dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-311296a1-a2d9-4069-86de-2918aa6e10dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Detecting the inner corners of the chessboard with its coordinates/pixels

# %%
# Detection of chessboard
import cv2
import numpy as np
from google.colab.patches import cv2_imshow  # Import cv2_imshow for google colab TODO Change to actual cv2

# Preprocessing the Image
image_path = "test.jpg"
image = cv2.imread(image_path) # Read Image
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # Grayscale the image

# Display the grayscale image
print("Gray Scaled Image")
cv2_imshow(gray)
#cv2.waitKey(0)  # Wait for a key press to close the window
cv2.destroyAllWindows()  # Close all OpenCV windows


# Detect the chessboard inner corners
board_size = (7, 7)  # To detect the inner corners of the chessboard 7x7
found, corners = cv2.findChessboardCorners(gray, board_size, None) # cv2 function to find inner corners

if found:
    # Draw the detected corners
    cv2.drawChessboardCorners(image, board_size, corners, ret)

    # Show the image with detected corners
    print("Detected corners")
    cv2_imshow(image)
    #cv2.waitKey(0)  # Wait for a key press to close the window
    cv2.destroyAllWindows()  # Close all OpenCV windows
    #print(corners)

else:
    # not found chessboard
    print("Chessboard not detected.")
# Out:
# Gray Scaled Image
# <PIL.Image.Image image mode=L size=416x416>
# Detected corners
# <PIL.Image.Image image mode=RGB size=416x416>

# %%
if ret:
    # Refine corner positions for subpixel accuracy
    cv2.cornerSubPix(gray, corners, (11, 11), (-1, -1),
                     criteria=(cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.1))

    # Ensure corners are in the correct shape (2D array of shape (num_corners, 2))
    corners = corners.reshape(-1, 2)
    # Draw the detected corners on the chessboard
    cv2.drawChessboardCorners(image, board_size, corners, ret)

    # Label the squares by drawing rectangles around each one
    rows, cols = board_size
    for i in range(rows - 1):
        for j in range(cols - 1):
            pt1 = tuple(corners[i * cols + j])
            pt2 = tuple(corners[i * cols + (j + 1)])
            pt3 = tuple(corners[(i + 1) * cols + j])
            pt4 = tuple(corners[(i + 1) * cols + (j + 1)])
            points = np.array([pt1, pt2, pt4, pt3], dtype=np.int32)
            cv2.polylines(image, [points], isClosed=True, color=(0, 255, 0), thickness=2)

    # Show the image with labeled squares
    cv2_imshow(image)
    cv2.destroyAllWindows()


else:
    print("Chessboard not detected.")
# Out:
# <PIL.Image.Image image mode=RGB size=416x416>

# %%
if ret:
    # Refine corner positions for subpixel accuracy
    cv2.cornerSubPix(gray, corners, (11, 11), (-1, -1),
                     criteria=(cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.1))
    # Ensure corners are in the correct shape (2D array of shape (num_corners, 2))
    corners = corners.reshape(-1, 2)

    """

    # X Y
    #print(corners)
    #print(corners[0])
    print(corners[0][0])
    print(corners[1][0])
    print(abs(corners[0][0] - corners[1][0]))


    TopLeftCorner = (abs(corners[0][0] - corners[1][0]), abs(corners[0][1] - corners[1][1]))
    print(TopLeftCorner)
    """
    # Get the four corners

    # Get the four inner corners
    top_left = corners[0]  # First corner (top-left)
    top_right = corners[board_size[0] - 1]  # Last corner of the first row (top-right)
    bottom_left = corners[(board_size[1] - 1) * board_size[0]]  # First corner of the last row (bottom-left)
    bottom_right = corners[(board_size[1]) * board_size[0] - 1]  # Last corner of the last row (bottom-right)

    avg_horizontal_dist = abs(top_right[0] - top_left[0]) / (board_size[0] - 1)
    avg_vertical_dist = abs(top_right[1] - bottom_right[1]) / (board_size[1] - 1)

    # Extrapolate outer corners
    outer_top_left = (top_left[0] + avg_horizontal_dist, top_left[1] + avg_vertical_dist)
    outer_top_right = (top_right[0] - avg_horizontal_dist, top_right[1] + avg_vertical_dist)
    outer_bottom_left = (bottom_left[0] + avg_horizontal_dist, bottom_left[1] - avg_vertical_dist)
    outer_bottom_right = (bottom_right[0] - avg_horizontal_dist, bottom_right[1] - avg_vertical_dist)

    # Draw outer squares (using polylines for example)
    outer_corners = np.array([outer_top_left, outer_top_right, outer_bottom_right, outer_bottom_left], dtype=np.int32)
    cv2.polylines(image, [outer_corners], isClosed=True, color=(0, 0, 255), thickness=2)
    # Draw circles on the four corners only
    cv2.circle(image, tuple(map(int, outer_top_left)), 10, (0, 255, 0), -1)  # Green circle for top-left
    cv2.circle(image, tuple(map(int, top_right)), 10, (0, 255, 0), -1)  # Green circle for top-right
    cv2.circle(image, tuple(map(int, bottom_left)), 10, (0, 255, 0), -1)  # Green circle for bottom-left
    cv2.circle(image, tuple(map(int, bottom_right)), 10, (0, 255, 0), -1)  # Green circle for bottom-right

    # Show the image with just the four corners marked
    cv2_imshow(image) #TODO
    cv2.destroyAllWindows()

else:
    print("Chessboard not detected.")
# Out:
# <PIL.Image.Image image mode=RGB size=416x416>

# %% [markdown]
# # Neuer Abschnitt
